# %% [markdown]
# # Import Important Shtuff

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from tqdm import trange

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %% [markdown]
# # Loading Up The Data

# %%
import gzip
import struct

# %%
def load_mnist(path, kind='train'):
    if(kind == 'test'):
        kind = 't10k'

    labels_path = os.path.join(path, f'{kind}-labels-idx1-ubyte')
    images_path = os.path.join(path, f'{kind}-images-idx3-ubyte')

    # Load labels
    with open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack(">II", lbpath.read(8))
        labels = np.frombuffer(lbpath.read(), dtype=np.uint8)

    # Load images
    with open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack(">IIII", imgpath.read(16))
        images = np.frombuffer(imgpath.read(), dtype=np.uint8) / 255
        # print(magic, num, rows, cols)

    return images, labels

# %%
def show_images(images, title_texts):
    cols = 5
    rows = int(len(images)/cols) + 1
    plt.figure(figsize=(30,20))
    index = 1    
    for x in zip(images, title_texts):        
        image = x[0]        
        title_text = x[1]
        plt.subplot(rows, cols, index)        
        plt.imshow(image, cmap=plt.cm.gray)
        if (title_text != ''):
            plt.title(title_text, fontsize = 15);        
        index += 1

# %%
to_see_X, to_see_y = load_mnist('../mnist-data/', kind='train')

# %%
to_see_X = to_see_X.reshape(60000, 28, 28)

# %%
images_2_show = []
titles_2_show = []

for i in range(0, 20):
    r = np.random.randint(1, 60000)
    images_2_show.append(to_see_X[r])
    titles_2_show.append('training image [' + str(r) + '] = ' + str(to_see_y[r]))

show_images(images_2_show, titles_2_show)

# %% [markdown]
# # Useful Functions

# %%
def create_batches(data, batch_size):
    batches = []
    for i in range(0, data.shape[0], batch_size):
        batch = data[i : i + batch_size]
        if(len(data.shape) > 1):
            batch_size, img_height, img_width = batch.shape
            batch = batch.reshape(batch_size, 1 , img_height, img_width)
        batches.append(batch)
    return np.array(batches, dtype=object)

# %%
def calculate_accuracy(y_pred, y_true):
    if len(y_pred.shape) == 2:
        y_pred = np.argmax(y_pred, axis=1)
    accuracy = np.mean(y_pred == y_true)
    return accuracy

# %% [markdown]
# # Training Pipeline

# %%
from sklearn.model_selection import train_test_split
from Model import LeNet
from utils.Optimizers import Adam

# %%
# Load the Data
X, y = load_mnist('../mnist-data/', kind='train')
X = X.reshape(60000, 28, 28)

# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.1, random_state=42, shuffle=True
)

# Define Model
model = LeNet()

# Define Hyperparameters
optimizer = Adam()
learning_rate = 0.001
epochs = 10
batch_size = 64

# Create Batches
X_train_batches = create_batches(X_train, batch_size)
y_train_batches = create_batches(y_train, batch_size)

# Track Loss and Accuracy
training_loss_per_epoch = []
training_accuracy_per_epoch = []
validation_loss_per_epoch = []
validation_accuracy_per_epoch = []

# start_time = time.time()

# Training Loop
for epoch in trange(epochs, desc="Training Epochs"):
    # Training Phase
    train_epoch_loss = []
    train_epoch_accuracy = []

    batch_num = 0
    for X_batch, y_batch in zip(X_train_batches, y_train_batches):
        start_time = time.time()
        
        # forward pass
        predictions = model.forward(X_batch, y_batch)
        # calculate loss and accuracy
        train_epoch_loss.append(model.loss_activation.loss_value)
        train_epoch_accuracy.append(calculate_accuracy(predictions, y_batch))
        # backward pass
        model.backward(predictions, y_batch)
        # update params
        optimizer.pre_update_params()
        optimizer.update_params(model.conv1)
        optimizer.update_params(model.conv2)
        optimizer.update_params(model.dense1)
        optimizer.update_params(model.dense2)
        optimizer.update_params(model.dense3)
        optimizer.post_update_params()
        
        end_time = time.time()

        batch_num += 1
        print(f"time taken for batch {batch_num}: {end_time - start_time}")
    
    training_loss_per_epoch.append(np.mean(train_epoch_loss))
    training_accuracy_per_epoch.append(np.mean(train_epoch_accuracy))

    # Validation Phase
    val_prediction = model.forward(X_val, y_val)
    
    validation_loss_per_epoch.append(model.loss_activation.loss_value)
    validation_accuracy_per_epoch.append(calculate_accuracy(val_prediction, y_val))

# end_time = time.time()
# Out:
# Training Epochs:   0%|                                                                          | 0/10 [00:00<?, ?it/s]
# time taken for batch 1: 11.920432090759277
# time taken for batch 2: 9.596925258636475
# time taken for batch 3: 9.350961685180664
# time taken for batch 4: 9.295505285263062
# time taken for batch 5: 9.283583402633667
# time taken for batch 6: 9.407996892929077
# time taken for batch 7: 9.053712606430054
# time taken for batch 8: 9.110759258270264
# time taken for batch 9: 9.536931276321411
# time taken for batch 10: 9.365569829940796
# time taken for batch 11: 9.607736349105835
# time taken for batch 12: 9.519951343536377
# time taken for batch 13: 9.22555422782898
# time taken for batch 14: 9.56413221359253
# time taken for batch 15: 9.514529705047607
# time taken for batch 16: 9.431721448898315
# time taken for batch 17: 9.65308928489685
# time taken for batch 18: 9.972843408584595
# time taken for batch 19: 11.303886651992798
# time taken for batch 20: 9.87308931350708
# time taken for batch 21: 9.69263482093811
# time taken for batch 22: 9.425620794296265
# time taken for batch 23: 9.464688301086426
# time taken for batch 24: 9.519273042678833
# time taken for batch 25: 9.108011245727539
# time taken for batch 26: 10.113481998443604
# time taken for batch 27: 9.74410605430603
# time taken for batch 28: 9.919129133224487
# time taken for batch 29: 10.493908405303955
# time taken for batch 30: 10.314377784729004
# time taken for batch 31: 12.623265743255615
# time taken for batch 32: 10.034921407699585
# time taken for batch 33: 9.441453695297241
# time taken for batch 34: 9.751542329788208
# time taken for batch 35: 9.634538173675537
# time taken for batch 36: 9.419105768203735
# time taken for batch 37: 9.065280437469482
# time taken for batch 38: 9.796260356903076
# time taken for batch 39: 10.403127193450928
# time taken for batch 40: 9.866782426834106
# time taken for batch 41: 10.101013422012329
# time taken for batch 42: 9.92645812034607
# time taken for batch 43: 10.325337648391724
# time taken for batch 44: 9.934795379638672
# time taken for batch 45: 10.536001205444336
# time taken for batch 46: 9.645412683486938
# time taken for batch 47: 11.53587555885315
# time taken for batch 48: 9.82671046257019
# time taken for batch 49: 9.149851083755493
# time taken for batch 50: 9.09275197982788
# time taken for batch 51: 9.095776796340942
# time taken for batch 52: 9.123878717422485
# time taken for batch 53: 9.435472011566162
# time taken for batch 54: 10.487112283706665
# time taken for batch 55: 9.944559812545776
# time taken for batch 56: 9.974150896072388
# time taken for batch 57: 9.738225221633911
# time taken for batch 58: 10.159400224685669
# time taken for batch 59: 10.072839260101318
# time taken for batch 60: 9.922656774520874
# time taken for batch 61: 9.630473375320435
# time taken for batch 62: 10.073251724243164
# time taken for batch 63: 9.990713596343994
# time taken for batch 64: 9.838857173919678
# time taken for batch 65: 10.45243763923645
# time taken for batch 66: 10.156264305114746
# time taken for batch 67: 9.911396741867065
# time taken for batch 68: 9.951974391937256
# time taken for batch 69: 10.713024377822876
# time taken for batch 70: 9.688305616378784
# time taken for batch 71: 9.525946855545044
# time taken for batch 72: 9.441162824630737
# time taken for batch 73: 10.134406805038452
# time taken for batch 74: 9.486732244491577
# time taken for batch 75: 9.506129503250122
# time taken for batch 76: 14.726733684539795
# time taken for batch 77: 19.209717512130737
# time taken for batch 78: 19.025465488433838
# time taken for batch 79: 19.37906813621521
# time taken for batch 80: 18.327038288116455
# time taken for batch 81: 18.85244655609131
# time taken for batch 82: 18.631587505340576
# time taken for batch 83: 18.56438136100769
# time taken for batch 84: 19.181337118148804
# Training Epochs:   0%|                                                                          | 0/10 [15:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 41
#      39 start_time = time.time()
#      40 # forward pass
# ---> 41 predictions = model.forward(X_batch, y_batch)
#      42 # calculate loss and accuracy
#      43 train_epoch_loss.append(model.loss_activation.loss_value)
#
# File D:\deep learning\cnn-from-scratch\models\Model.py:36, in LeNet.forward(self, X, y, type)
#      34 def forward(self, X, y, type='train'):
#      35     # Convolutional Layers (inputs.shape = (batch_size, in_channels, img_height, img_width))
# ---> 36     self.conv1.forward(X)
#      37     self.activation1.forward(self.conv1.output)
#      38     self.maxpool1.forward(self.activation1.output)
#
# File D:\deep learning\cnn-from-scratch\utils\ConvLayers.py:49, in Convolutional.forward(self, inputs)
#      46                 w_end = w_start + self.kernel_width
#      48                 region = inputs[batch_idx, :, h_start : h_end, w_start : w_end]
# ---> 49                 output[batch_idx, out_ch, out_row, out_col] = np.sum(region * self.weights[out_ch]) + self.biases[out_ch]
#      51 self.output = output
#
# KeyboardInterrupt:

# %% [markdown]
# #### heck this is taking wayyy too long 💀
# (try training if you have a good cpu)

# %% [markdown]
# # Testing the Model

# %%
X_test, y_test = load_mnist('../mnist-data/', kind='test')
X_test = X_test.reshape(10000, 1, 28, 28)

# %%
images_2_show = []
titles_2_show = []

for i in range(0, 10):
    r = np.random.randint(1, 10000)
    images_2_show.append(X_test.reshape(10000, 28, 28)[r])
    titles_2_show.append('test image [' + str(r) + '] = ' + str(y_test[r]))

show_images(images_2_show, titles_2_show)

# %%
test_predictions = model.forward(X_test, y_test, type='test')
test_predictions = np.argmax(test_predictions, axis=1)
print(f"loss: {model.loss_activation.loss_value:.4f}")
print(f"accuracy: {calculate_accuracy(test_predictions, y_test)}")
# Out:
# loss: 2.2371
# accuracy: 0.2378

# %% [markdown]
# # 💀💀💀
